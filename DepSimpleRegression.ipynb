# %%
import pickle # library needed to access the trained module

# %%
load_model=pickle.load(open("finalized_model.sav",'rb')) #loading trained model

# %%
result=load_model.predict([[0]])
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
